# %%
from PIL import Image, ImageDraw, ImageFont


square_size = 100
size = 7
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")

draw_grid(draw, size, square_size, size*square_size)
    

square_num = size * size
point = [0,0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                if counter < 10:
                    draw.text(((point[0] + size/2) * square_size - 12, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               str(counter), fill="black", font=font)
                elif counter < 100 and counter > 9:
                    draw.text(((point[0] + size/2) * square_size - 20, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               str(counter), fill="black", font=font)
                else:
                    draw.text(((point[0] + size/2) * square_size - 35, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               str(counter), fill="black", font=font)
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break
        
img.save('numbered_spiral.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import math


square_size = 100
size = 13
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")

draw_grid(draw, size, square_size, size*square_size)
    
square_num = size * size
point = [0, 0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                x_pos = (point[0] + size/2) * square_size - 50
                y_pos = (point[1] * -1 + size/2) * square_size - 50
                if counter == 1 or counter == 10 or counter == 51 or counter == 124:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="salmon")
                text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                draw.text(((point[0] + size/2) * square_size + text_offset, 
                           (point[1] * -1 + size/2) * square_size - 15), 
                           str(counter), fill="black", font=font)
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break

center_x = (size // 2) * square_size
center_y = (size // 2) * square_size
start_point = (center_x + square_size // 2, center_y + square_size // 2)

angle_radians = 7.41 / 4 * math.pi

line_length = size * square_size
end_x = start_point[0] + line_length * math.cos(angle_radians)
end_y = start_point[1] - line_length * math.sin(angle_radians)
end_point = (end_x, end_y)

draw.line([start_point, end_point], fill="blue", width=2)
        
img.save('numbered_spiral_highlighted.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import math

square_size = 100
size = 13
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")

draw_grid(draw, size, square_size, size*square_size)
    
square_num = size * size
point = [0, 0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                x_pos = (point[0] + size/2) * square_size - 50
                y_pos = (point[1] * -1 + size/2) * square_size - 50
                if counter == 1 or counter == 27 or counter == 125:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="salmon")
                text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                draw.text(((point[0] + size/2) * square_size + text_offset, 
                           (point[1] * -1 + size/2) * square_size - 15), 
                           str(counter), fill="black", font=font)
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break

center_x = (size // 2) * square_size
center_y = (size // 2) * square_size
start_point = (center_x + square_size // 2, center_y + square_size // 2)

angle_radians = 7.586 / 4 * math.pi

line_length = size * square_size
end_x = start_point[0] + line_length * math.cos(angle_radians)
end_y = start_point[1] - line_length * math.sin(angle_radians)
end_point = (end_x, end_y)

draw.line([start_point, end_point], fill="blue", width=2)
        
img.save('numbered_spiral_highlighted_1.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import math

square_size = 100
size = 13
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")

draw_grid(draw, size, square_size, size*square_size)
    
square_num = size * size
point = [0, 0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                x_pos = (point[0] + size/2) * square_size - 50
                y_pos = (point[1] * -1 + size/2) * square_size - 50
                if counter == 1 or counter == 11 or counter == 53 or counter == 127:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="salmon")
                text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                draw.text(((point[0] + size/2) * square_size + text_offset, 
                           (point[1] * -1 + size/2) * square_size - 15), 
                           str(counter), fill="black", font=font)
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break

center_x = (size // 2) * square_size
center_y = (size // 2) * square_size
start_point = (center_x + square_size // 2, center_y + square_size // 2)

angle_radians = 0

line_length = size * square_size
end_x = start_point[0] + line_length * math.cos(angle_radians)
end_y = start_point[1] - line_length * math.sin(angle_radians)
end_point = (end_x, end_y)

draw.line([start_point, end_point], fill="blue", width=2)
        
img.save('numbered_spiral_highlighted_2.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import math

square_size = 100
size = 5
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")
    
square_num = size * size
point = [0, 0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                x_pos = (point[0] + size/2) * square_size - 50
                y_pos = (point[1] * -1 + size/2) * square_size - 50
                if counter == 2 or counter == 11 or counter == 12:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="indianred")
                if counter == 3 or counter == 13 or counter == 14:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="orange")
                if counter == 4 or counter == 15 or counter == 16:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="peachpuff")
                if counter == 5 or counter == 17 or counter == 18:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="salmon")
                if counter == 6 or counter == 19 or counter == 20:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="brown")
                if counter == 7 or counter == 21 or counter == 22:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="lightcoral")
                if counter == 8 or counter == 23 or counter == 24:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="sandybrown")
                if counter == 9 or counter == 10 or counter == 25:
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="mistyrose")

                if counter == 15:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q3", fill="black", font=font)
                if counter == 19:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q5", fill="black", font=font)
                if counter == 23:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q7", fill="black", font=font)
                if counter == 11:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q1", fill="black", font=font)
                if counter == 13:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q2", fill="black", font=font)
                if counter == 17:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q4", fill="black", font=font)
                if counter == 21:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q6", fill="black", font=font)
                if counter == 25:
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               "q8", fill="black", font=font)
                
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break
        
draw_grid(draw, size, square_size, size*square_size)
        
img.save('numbered_spiral_highlighted_3.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import math

prime_list = []
def check_prime(number):
    is_prime = True
    if number != 1:
        for i in prime_list:
            if number % i == 0:
                is_prime = False
        if is_prime:
            prime_list.append(number)
    return is_prime

square_size = 100
size = 13
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")

draw_grid(draw, size, square_size, size*square_size)
    
square_num = size * size
point = [0, 0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                x_pos = (point[0] + size/2) * square_size - 50
                y_pos = (point[1] * -1 + size/2) * square_size - 50
                if check_prime(counter):
                    text_offset = -12 if counter < 10 else (-20 if counter < 100 else -35)
                    draw.text(((point[0] + size/2) * square_size + text_offset, 
                               (point[1] * -1 + size/2) * square_size - 15), 
                               str(counter), fill="black", font=font)
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break

center_x = (size // 2) * square_size
center_y = (size // 2) * square_size
start_point = (center_x + square_size // 2, center_y + square_size // 2)

angle_radians = 7.586 / 4 * math.pi

line_length = size * square_size
end_x = start_point[0] + line_length * math.cos(angle_radians)
end_y = start_point[1] - line_length * math.sin(angle_radians)
end_point = (end_x, end_y)

img.save('numbered_spiral_highlighted_5.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import math

prime_list = []
def check_prime(number):
    is_prime = True
    if number != 1:
        for i in prime_list:
            if number % i == 0:
                is_prime = False
        if is_prime:
            prime_list.append(number)
    return is_prime

square_size = 100
size = 201
img = Image.new(mode="RGB", size=(size*square_size, size*square_size), color="white")
draw = ImageDraw.Draw(img)

try:
    font = ImageFont.truetype("arial.ttf", square_size - 60)
except IOError:
    font = ImageFont.load_default()

def draw_grid(draw, grid_size, square_size, img_size):
    for i in range(grid_size + 1):
        draw.line((i*square_size, 0, i*square_size, img_size), fill="gray")
        draw.line((0, i*square_size, img_size, i*square_size), fill="gray")

square_num = size * size
point = [0, 0]
counter = 1
iteration = 0
for k in range(square_num):
    if counter <= square_num:
        if 2*k == iteration:
            iteration = 0
            k += 1

        for j in range(2):
            for _ in range(k):
                x_pos = (point[0] + size/2) * square_size - 50
                y_pos = (point[1] * -1 + size/2) * square_size - 50
                if check_prime(counter):
                    draw.rectangle([x_pos, y_pos, x_pos + square_size, y_pos + square_size], fill="salmon")
                if k % 2 == 0:
                    point[j] -= 1
                else:
                    point[j] += 1
                iteration += 1
                counter += 1
    else:
        break

center_x = (size // 2) * square_size
center_y = (size // 2) * square_size
start_point = (center_x + square_size // 2, center_y + square_size // 2)

angle_radians = 7.586 / 4 * math.pi

line_length = size * square_size
end_x = start_point[0] + line_length * math.cos(angle_radians)
end_y = start_point[1] - line_length * math.sin(angle_radians)
end_point = (end_x, end_y)    

img.save('numbered_spiral_highlighted_6.png')
